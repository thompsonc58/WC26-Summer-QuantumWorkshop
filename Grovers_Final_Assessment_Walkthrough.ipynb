# %% [markdown]
# # Grover's Algorithm Final Assessment Walkthrough
# This notebook summarizes the assessment workflow.

# %% [markdown]
# ## Workflow
# 1. Initialize
# 2. Oracle
# 3. Diffusion
# 4. Measurement
# 5. Execute

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit_aer import AerSimulator

qr=QuantumRegister(3,'q')
cr=ClassicalRegister(3,'c')
qc=QuantumCircuit(qr,cr)

qc.h(qr)
# TODO: Build Oracle
# TODO: Build Diffusion Operator
qc.measure(qr,cr)

backend=AerSimulator()
result=backend.run(qc,shots=1024).result()
print(result.get_counts())

# %% [markdown]
# ## Key Concepts
# - Hadamard creates superposition.
# - Oracle phase-flips the marked state.
# - Diffusion amplifies the marked state's probability.
# - Measurement collapses the quantum state.
# - Highest count should be the marked state.
