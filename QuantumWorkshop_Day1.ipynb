# %% [markdown]
# # Introduction to Quantum Computing
# <img src="https://raw.githubusercontent.com/FSCJ-FacultyDev/WC26-Summer-QuantumWorkshop/main/images/quantum-core.png"
#      alt="QUANTUM-CORE"
#      width="50%">

# %% [markdown]
# ### Prof. David Singletary
# ### Florida State College at Jacksonville

# %% [markdown]
# # Day 1: Foundations of Quantum Computing
# - Welcome and Introductions
# - Classical vs. Quantum Computation
# - Qubits, Superposition, and Measurement
# - Day 1 Hands-on: Visualizing Single-Qubit States in Colab

# %% [markdown]
# # Welcome and Introductions
#
# Thank you for enrolling in this workshop. The material I will be presenting consists of excerpts from various reference sources that are listed at the end of the workshop materials.

# %% [markdown]
# # Classical vs. Quantum Computation

# %% [markdown]
# ## Essential Quantum Mechanics
#
# **“I think I can safely say that nobody understands quantum mechanics.”**
# — Richard Feynman (1965)
#
# Quantum mechanics principles are essential for constructing quantum hardware, but they are not the primary focus when learning quantum computing concepts.
# - Instead, we’ll focus on simple models and algorithms that help explain how quantum information behaves, without getting into the physics.
#
# While you don’t need deep physics to understand the basics of quantum computers, the following ideas can help explain why quantum computing behave differently from classical ones:
#
# 1. **Superposition:** a quantum system can exist in multiple states at the same time (e.g., both 0 and 1). This is what allows quantum computers to process many possibilities simultaneously.
#
#    ▶ [Watch: Superposition Explained](https://www.youtube.com/watch?v=IHDMJqJHCQg)
#
# 2. **Measurement:** observing a quantum system forces it to “choose” one outcome from many possibilities. This is why quantum results are inherently uncertain, which is why programs must be run many times.
#
#     - In (Griffiths & Schroeter, 2018) quantum measurement is characterized as follows:
#       - Given a quantum particle at position C, any experiment to measure its position can only provide statistical information about its probable results. The main schools of thought regarding this indeterminacy are:
#       1. **The realist position:** the particle really was at position C.
#       2. **The orthodox position:** the particle wasn't really anywhere; the act of measurement forced it to "take a stand".
#       3. **The agnostic position:** refuse to answer the question.
#
# 3. **Entanglement:** Two or more particles can become linked so that the state of one is related to the state of another. This enables coordinated behavior that is essential for real quantum computation.
#
#    ▶ [Watch: Entanglement Explained](https://www.youtube.com/watch?v=rqmIVeheTVU)
#
# 4. **Probability Distributions:** Quantum results follow probability patterns rather than producing a single fixed answer. Results are interpreted statistically, not as one “correct” output.
#
# 5. **Noise:** Real quantum systems are affected by environmental interference, which introduces errors. This is why quantum results are imperfect and why error mitigation is an important area of research.

# %% [markdown]
# ## Quantum Computing Terminology
#
# 1. **Quantum Advantage:** The performance benefit quantum computers can achieve over classical computers for certain problem types, such as simulating quantum systems or performing specific searches more efficiently.
#
# 2. **Quantum Parallelism:** The ability of a quantum computer to apply one operation to many possible values at the same time, similar to an unlimited SIMD (Single Instruction, Multiple Data) model, enabling faster computation.
#
# ![SIMD](https://raw.githubusercontent.com/FSCJ-FacultyDev/WC26-Summer-QuantumWorkshop/main/images/simd.png)
#
#   - One operation acts on many possibilities at once, like SIMD.
#   - **But** you never see the intermediate values.
#   - The computation reshapes a probability distribution using interference:
#     - Good answers are amplified
#     - Bad answers are suppressed
#   - Measurement gives you one sample, not the full state.
#
# 3. **Shot:** A single execution of a quantum circuit that produces one  outcome. Because results are probabilistic, many shots are run to estimate the full probability distribution of possible outcomes.
#
# 4. **Quantum State:** A mathematical description of a quantum system that encodes all possible outcomes of a computation, along with their probabilities and relative phase (direction) information.
#
# 5. **Amplitude:** A value that indicates how much each possible state contributes to the overall system, with its square giving the probability of observing that state when measured.
#
# 6. **Interference:** The process by which quantum amplitudes combine so that some outcomes reinforce each other (constructive interference) while others cancel out (destructive interference). Quantum algorithms use interference to amplify the probability of correct answers and suppress incorrect ones.
#
# 7. **Phase**: an angle associated with an amplitude that influences interference between states.
#
# 8. **Butterfly Pattern:** A structure of quantum operations where pairs of values are repeatedly recombined in parallel to shape the final probability distribution before measurement.
#
# 9. **Qubit (Quantum Bit):** The basic unit of information in a quantum computer. Unlike a classical bit that is either 0 or 1, a qubit can exist in a superposition of both states at the same time, and can also become entangled with other qubits to enable powerful quantum computations.

# %% [markdown]
# ## A Note on Complex Numbers
#
# - A complex number has a real part and an imaginary part, often written as
# ```z = x + iy```
# - This can be visualized on the complex plane, where the horizontal axis represents the real part and the vertical axis represents the imaginary part.
#
# <img src="https://raw.githubusercontent.com/FSCJ-FacultyDev/WC26-Summer-QuantumWorkshop/main/images/plotting-complex-numbers.png"
#       alt="Plotting Complex Numbers"
#       width="75%">
# (3Blue1Brown, 2016)
#
# - A complex number can also be described in polar form by its magnitude (distance from the origin) and its phase (the angle from the real axis).
#
# - **Magnitude**
#
# $$
# r = \sqrt{x^2 + y^2}
# $$
#
# - **Phase**
#
# $$
# \theta = \tan^{-1}\left(\frac{4}{3}\right) \approx 53.13^\circ
# $$
#
# - with a final polar form of
#
#   z = r(cosθ + i * sinθ)
#
#   z = 5(cos(53.13) + i * sin(53.13))
#
# <img src="https://raw.githubusercontent.com/FSCJ-FacultyDev/WC26-Summer-QuantumWorkshop/main/images/plotting-complex-numbers2.png"
#       alt="Plotting Complex Numbers - Polar"
#       width="75%">
#
# (3Blue1Brown, 2016)
#
# In quantum computing, the magnitude of an amplitude determines measurement probability (after squaring it), while the phase influences how quantum states interfere during computation.

# %% [markdown]
# ## Why Quantum?
#
# Quantum computing offers speedups beyond classical scaling for select problems (e.g., Fourier transforms, search, simulation). This is known as the **quantum advantage**.
#
# ![QuantumVsClassical](https://raw.githubusercontent.com/FSCJ-FacultyDev/WC26-Summer-QuantumWorkshop/main/images/quantum-vs-classical.png)
#
# Computations that are impractical classically (quantum physics, chemistry, true randomness) are significantly faster
# - e.g., in chemistry, predicting a molecule’s energy levels requires modeling how many interacting electrons behave under quantum mechanics.
#   - Each additional electron doubles the size of the system’s state space, causing classical simulations to scale exponentially in time and memory.
# - Even powerful classical supercomputers struggle with accurate simulations for moderately sized molecules (beyond a few dozen interacting electrons).
#   - A quantum computer represents electron states directly using qubits, allowing it to naturally model superposition and entanglement.
# - Quantum algorithms can estimate molecular energy levels with far fewer resources, enabling applications such as drug discovery, catalyst design, and materials science.
#
# ![MoleculeCost](https://raw.githubusercontent.com/FSCJ-FacultyDev/WC26-Summer-QuantumWorkshop/main/images/molecule-cost.png)

# %% [markdown]
# In addition to speedups and reduction of resources, quantum computers can perform some computations that classical computers cannot, such as
# - **quantum modeling:** They can simulate molecular behavior at the quantum level, which is useful for applications such as drug discovery and energy technologies.
# - **true randomness:** Quantum systems produce inherently random outcomes, unlike classical systems that rely on deterministic algorithms or pseudo-random number generators.
#   - This is especially valuable for cryptography and security applications

# %% [markdown]
# ## A Brief Timeline of Quantum Computing
#
# - Starting with the waybacks of quantum theory itself:
#   - Max Planck (1900): Introduced the idea that energy is emitted in discrete packets called quanta, laying the foundation for quantum theory.
#   - Albert Einstein (1905): Proposed that light behaves as particles (photons), explaining the photoelectric effect and reinforcing quantum ideas.
#   - Niels Bohr (1913): Developed an early quantum model of the atom with quantized energy levels.
#
#     <img src="https://raw.githubusercontent.com/FSCJ-FacultyDev/WC26-Summer-QuantumWorkshop/main/images/bohr.png"
#         alt="Niels Bohr"
#         width="25%">
#
#     (The Economic Times, 2026)
#
#     <details>
#     <summary><strong>Do not click here!</strong></summary>
#     <p>You were warned.</p>
#     <img src="https://raw.githubusercontent.com/FSCJ-FacultyDev/WC26-Summer-QuantumWorkshop/main/images/bohrge.png"
#         alt="Niels Bohr with Googly Eyes"
#         width="25%">
#     </details>
#
#   - Max Born (1926): Interpreted quantum mechanics probabilistically, linking the wavefunction to measurement outcomes.
#   - Werner Heisenberg (1925): Developed matrix mechanics, the first complete mathematical framework for quantum mechanics.
#   - Erwin Schrödinger (1926): Formulated wave mechanics, offering an alternative but equivalent description of quantum systems.
#
# - 1960s-1970s: Early ideas in quantum information began to appear.
# - 1980s: Researchers showed that computers could be described using quantum mechanics.
# - 1990s: Important quantum algorithms such as Shor’s and Grover’s were developed.
# - 1990s: Early quantum hardware experiments began.
# - 2000s: More small experimental quantum computers were built.
# - 2000s: Researchers explored different hardware approaches, including ions, photons, and superconducting systems.
# - 2010s: Quantum computing grew quickly, with better devices and more public access through the cloud.
# - 2010s: Companies like IBM, Google, and D-Wave became major players.
# 2020s: Progress focused on scaling up, improving error correction, and building quantum networks.
#
# (Wikipedia contributors, n.d.)

# %% [markdown]
# ## Quantum Computing Is Becoming a Practical Developer Skill
# - Hardware maturity is driving real adoption and demand for “quantum-ready” developers
# - Focus is shifting from physics to applied math and software abstractions
# - Developers must recognize when quantum, classical, or hybrid approaches fit best
#   - You're not being hired as a physicist, you're being hired as a developer who can work with quantum systems (heard this before for data science and AI)
#   ### Steve Suarez (HorizonX CEO, Senior Advisor McKinsey, Harvard & MIT Alumnus via LinkedIn)
#   - Current global quantum workforce estimates (among “pure-play” quantum companies) at around ~14,500 as of 2024.
#   - Open positions in the U.S. roughly 7,400 job & internship openings in 2024.
#   - Projections of up to ~250,000 quantum-related roles globally by 2030, and potentially ~840,000 by 2035.
#     - Entry-level roles in the U.S. \$100,000 to \$140,000 per year.
#   - Recent analysis by Chicago Quantum Exchange: only ~29% of quantum-tech jobs required a PhD in 2023, while ~38% were open to bachelor’s degrees or less.
#   - A strong background in physics, mathematics, or computer science is still very much expected, and programming skills in Python, Qiskit, Cirq (or other quantum frameworks) are increasingly valued.
#
#   (Suarez, n.d.)
#
# - Quantum Software Developer: build algorithms using frameworks, implement circuits and simulations, optimize quantum programs
# - Hybrid Application Developer: combine classical and  quantum systems, write code that sends jobs to quantum hardware and processes results (pipelines), integrate quantum into existing applications
# - Quantum SDK / Platform Developer: build tools, APIs, and libraries for others
# - Algorithm Developer (architect level): design solutions for optimization, search, or simulation
# - Skillsets:
#   - Linear algebra (vectors, matrices)
#   - Probability and statistics
#   - Python + APIs
#   - Ability to think in systems and abstractions

# %% [markdown]
# <img src="https://raw.githubusercontent.com/FSCJ-FacultyDev/WC26-Summer-QuantumWorkshop/main/images/ibm-dev-roadmap.png"
#      alt="IBM DEV ROADMAP"
#      width="75%">

# %% [markdown]
# <img src="https://raw.githubusercontent.com/FSCJ-FacultyDev/WC26-Summer-QuantumWorkshop/main/images/ibm-osprey-chip.png"
#      alt="IBM OSPREY CHIP"
#      width="75%">
#
#
# <img src="https://raw.githubusercontent.com/FSCJ-FacultyDev/WC26-Summer-QuantumWorkshop/main/images/qubit-scorecard-2023.png"
#       alt="2023 Qubit Scorecard"
#       width="75%">
#       (QuSecure, n.d.)

# %% [markdown]
# ## Key Characteristics of Quantum Computing
#
# - Quantum parallelism: a quantum operation acts on all states in a superposition simultaneously.
# - Because operations modify all amplitudes at once, algorithms must be carefully designed to avoid unintended interference.
# - Measurement is probabilistic: a single run produces one outcome drawn from a probability distribution.
# - Repeated runs (“shots”) reveal the probability distribution of outcomes.
# - Measurement results appear as binary strings (e.g., 0101), representing the measured states of the qubits.
# - Unlike classical programs that return a deterministic result, quantum programs typically return samples from a probability distribution.

# %% [markdown]
# ## NIST Standardization
# - In August 2024, the National Institute of Standards and Technology (NIST) finalized its first post-quantum cryptography (PQC) standards—FIPS 203, 204, and 205 (National Institute of Standards and Technology [NIST], 2024)
#   - (FIPS = government-approved standards for how information is processed and secured)
# - These standards define new encryption and digital signature algorithms designed to remain secure against future quantum computers capable of breaking today’s cryptography.
# - The standards were developed through an eight-year international evaluation effort involving cryptography experts worldwide.
# - They are intended to protect critical digital information, including emails, e-commerce transactions, medical records, and national security data.
# - NIST is urging organizations to begin transitioning now, as adopting new cryptographic standards requires significant time and planning.
# - This standardization provides a trusted, interoperable, and widely accepted foundation, reducing fragmentation and enabling a coordinated global shift to quantum-resistant security before quantum threats become practical.

# %% [markdown]
# ## We're Not Alone
# - China is expected to establish official standards for post-quantum cryptography within about three years, signaling preparation for future quantum threats to current encryption methods.
# - The move reflects growing global urgency to transition to quantum-resistant security, as experts anticipate quantum computers could eventually break widely used cryptographic systems.
#
#   https://www.reuters.com/world/asia-pacific/china-likely-have-standards-post-quantum-crytography-3-years-expert-says-2026-03-19
#
# (Reuters, 2026)

# %% [markdown]
# # Demonstrating Quantum Parallelism
#
# We can demonstrate quantum parallelism by swapping odd and even components of an 8-element array.
#
# <img src="https://raw.githubusercontent.com/FSCJ-FacultyDev/WC26-Summer-QuantumWorkshop/main/images/table1-1-probability-pairs.png"
#      alt="Probability Pairs"
#      width="50%">

# %% [markdown]
# For a classical implementation, we can write out all the operations or use a for loop to execute sequentially
# - the number of operations necessary will grow linearly with
# the number of swaps we want to perform.
#
# <img src="https://raw.githubusercontent.com/FSCJ-FacultyDev/WC26-Summer-QuantumWorkshop/main/images/sequential-swap.png"
#      alt="Sequential Swap"
#      width="75%">

# %%
# explicit loop-based swap

values = [0.05, 0.11, 0.13, 0.02, 0.34, 0.17, 0.06, 0.12]

print('before swap:', values)
# swap adjacent elements (0↔1, 2↔3, 4↔5, 6↔7)
for i in range(0, len(values), 2):
    values[i], values[i+1] = values[i+1], values[i]

print('after swap:',values)

# %% [markdown]
# The code shown above is an example of an algorithm which uses explicit, conventional iteration (i.e., a loop).
#
# We can use Python slicing to demonstrate a more transparent version, which  removes the visible loop.

# %%
# slice-based swap

values = [0.05, 0.11, 0.13, 0.02, 0.34, 0.17, 0.06, 0.12]
print('before swap:', values)
values[::2], values[1::2] = values[1::2], values[::2]
print('after swap:',values)

# %% [markdown]
# This version appears to swap all adjacent elements at once, but the underlying implementation still performs conventional iteration
# - It is simply abstracted away in optimized C code.
#
# - The loop has not disappeared; it is just hidden.

# %% [markdown]
# Quantum state evolution is fundamentally different.
#
# We treat the state as one mathematical object that gets transformed in a single step.
#
# <img src="https://raw.githubusercontent.com/FSCJ-FacultyDev/WC26-Summer-QuantumWorkshop/main/images/quantum-swap.png"
#      alt="Quantum Swap"
#      width="50%">
#
# Instead of updating individual entries one-by-one, the entire state vector is multiplied by a transformation matrix.
# - The operation applies to all possibilities simultaneously because they are part of the same mathematical object.
# - In classical computing, even when iteration is hidden, individual elements are still processed independently.
# - In quantum computing, there are no independent values being iterated over; there is a single state evolving as a whole.

# %% [markdown]
# ## Quantum Algorithms
#
# - Programs evolve a quantum state across exponentially many outcomes in parallel (quantum parallelism, as described previously)
#   - Instead of checking each possibility one by one, quantum algorithms use simple repeated steps that mix the possibilities together.
# - They use linear transformations that recombine values in repeating “butterfly” patterns
#
#   <img src="https://raw.githubusercontent.com/FSCJ-FacultyDev/WC26-Summer-QuantumWorkshop/main/images/butterfly-pattern.png"
#      alt="Butterfly Pattern"
#      width="50%">
#
# - Think of this as stirring ingredients in a bowl; each simple step mixes everything together a little more, gradually increasing the amount of the “right” answer and reducing the rest.
#   - After this mixing process shapes the probabilities, measurement produces a single classical outcome (bit, integer, eigenvalue, etc.).
#   - The solution is not in a single run, but in the statistical pattern that appears across many runs.
#
# - Note that in the stirring analogy above, we do not know the right answer ahead of time; the algorithm is designed so that the structure of the problem causes the correct answers to amplify automatically.
#   - A quantum algorithm doesn’t “guess and boost.” Instead:
#   - The problem is encoded into a function (often called an **oracle**).
#   - That function marks correct solutions in a mathematically detectable way.
#   - The quantum circuit is built so that interference increases the amplitudes of those marked states.
#   - We are not manually choosing which answer to amplify; the problem structure determines it.
#
# ## Interference does the work
#
# Constructive interference increases amplitudes of states that satisfy the condition, while destructive interference suppresses the others through repeated linear transformations (the butterfly recombinations).
#
# ## Example: Grover’s Algorithm
# - Suppose one item in a database satisfies a condition, but we do not know which one.
# - The algorithm begins in an equal superposition, meaning every possible input starts with the same amplitude (and therefore the same probability).
# - A quantum circuit (an oracle, covered in more detail in Day 4) is designed to evaluate the condition f(x).
# - When applied to the superposition, it flips the phase of any state that satisfies the condition.
# - The function is applied to all possible inputs at once, without checking them individually.
# - Repeated mixing steps then use interference to increase the amplitude of the state that satisfies the condition.
# - When the system is measured, the correct item appears with high probability.
#
# ### How Does This Scale?
#
# <table>
#   <thead>
#     <tr>
#       <th>Database Size</th>
#       <th>Classical Checks</th>
#       <th>Quantum Iterations</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1,000</td>
#       <td>~1,000</td>
#       <td>~32</td>
#     </tr>
#     <tr>
#       <td>1,000,000</td>
#       <td>~1,000,000</td>
#       <td>~1,000</td>
#     </tr>
#     <tr>
#       <td>1,000,000,000</td>
#       <td>~1,000,000,000</td>
#       <td>~31,623</td>
#     </tr>
#   </tbody>
# </table>
#
# - You might still run 100-1000 shots to confirm the result, but the dominant cost is the algorithm itself, not the shots.
#
# - Common quantum algorithm patterns:
#   - Sampling from hard-to-generate distributions
#   - Searching for digital answers (e.g., Grover, Shor; includes cryptographic key search and factoring)
#   - Estimating probabilities via many shots (analog-style results)
#
# - Emphasis is on hardware- and library-agnostic thinking as the ecosystem evolves

# %% [markdown]
# # Day 1 Hands-On: Visualizing Single-Qubit States
#
# In this exercise, we will visualize a single qubit and observe how it changes under simple quantum operations. Rather than focusing entirely on physical hardware, we will start with conceptual and mathematical representations. The goal is to connect the conceptual ideas discussed earlier to concrete representations, showing how quantum states evolve and why repeated measurements are necessary to understand their statistical behavior.
#
# ### Representing a Qubit
# Let's start by giving a clearer view of what a qubit is. To do this we need to consider three separate viewpoints: conceptual, mathematical, and hardware.
#
# **Conceptual**
# - This is effectively a geometric view, where you see the qubit as a point on a **Bloch sphere**.
#
# <img src="https://raw.githubusercontent.com/FSCJ-FacultyDev/WC26-Summer-QuantumWorkshop/main/images/blochsphere.png"
#      alt="Bloch Sphere"
#      width="50%">
#
# - This gives us a conceptual view of a qubit as state, superposition, and phase.
# - It’s a model, like drawing vectors to explain forces; useful, but abstract.
# - Z-axis: represents basis states with real amplitudes. The north pole  represents |0⟩, and the south pole represents |1⟩.
#   - These quantum states are written in **Dirac notation** (also known as **bra-ket notation**), a standard way to write quantum states.
#     - Paul Dirac (https://simple.wikipedia.org/wiki/Paul_Dirac), a British theoretical physicist and one of the founders of quantum mechanics, who coined bra-ket
#   - **∣ψ⟩** is a ket representing a quantum state. (ψ is psi, pronounced "sigh")
#   - **⟨ψ∣** is the corresponding bra.
#   - When a bra is multiplied by a ket, such as ⟨φ|ψ⟩, the result is an **inner product**, a number that measures how similar two states are.
#   - The number inside (0 or 1) labels a particular basis state.
#   - |0⟩ means “the qubit is in the 0 basis state”, and |1⟩ means “the qubit is in the 1 basis state.”
#     - In most hardware implementations, |0⟩ is the **ground** state and |1⟩ is the **excited** (higher energy) state
#   - These are the quantum equivalents of classical 0 and 1, representing vectors in a two-dimensional state space.
# - X-axis: Runs left–right across the equator; represents real superpositions where amplitudes are in phase (e.g., |0⟩+|1⟩), associated with interference in the X basis.
# - Y-axis: Runs front–back across the equator; represents superpositions with a 90° imaginary phase difference (e.g., |0⟩+i|1⟩), highlighting the role of phase in quantum behavior.
# - Any point in between |0⟩ and |1⟩ represents a superposition: partly 0 and partly 1, with both magnitude and phase.
# - This is the cleanest way to visualize qubits vs. classical bits.
# - "Clean" is relative
#
#   <img src="https://raw.githubusercontent.com/FSCJ-FacultyDev/WC26-Summer-QuantumWorkshop/main/images/blochsphere-complex.png"
#     alt="Complex Bloch Sphere"
#     width="50%">
#
#     <sub>(Prof. nano, n.d.)</sub>
#
# **Mathematical**
# - A qubit can be written as 𝛼∣0⟩ + 𝛽∣1⟩ where 𝛼 and 𝛽 are complex numbers
# - This is the most precise definition, but there's nothing to “see.”
# - Physicists and algorithms live here.
#
# **Physical**
# - This is the hardware implementation and for this workshop, the most interesting and useful definition
# - It is what physically stores the qubit.
# - Depending on the hardware, this can be based on:
#
#   - A superconducting loop
#
#   ![TantalumQubit](https://raw.githubusercontent.com/FSCJ-FacultyDev/WC26-Summer-QuantumWorkshop/main/images/tantalum-qubit.png)
#
#   - A trapped ion
#
#       <img src="https://raw.githubusercontent.com/FSCJ-FacultyDev/WC26-Summer-QuantumWorkshop/main/images/trappedion-qubit.png"
#         alt="Trapped Ion Qubit"
#         width="50%">
#
#   - A photon’s polarization (photonic)
#
#       <img src="https://raw.githubusercontent.com/FSCJ-FacultyDev/WC26-Summer-QuantumWorkshop/main/images/photonic-qubit.png"
#         alt="Photonic Qubit"
#         width="50%">

# %% [markdown]
# ### Visualizing Superposition
# - The bar charts in the image shown below present various qubit amplitudes.
#   - Each bar represents the amplitude associated with the basis states ∣0⟩ and ∣1⟩.
#   - By visualizing these amplitudes, we can see how different quantum states are represented mathematically and how their amplitudes relate to measurement probabilities.
#
# - |0⟩ (ground state)
#   - The bar for |0⟩ is 1.
#   - The bar for |1⟩ is 0.
#   - This means the qubit is definitely in state 0.
#   - If we measure it, we will always get 0.
#   - This behaves exactly like a classical bit set to 0.
# - |1⟩ (excited state)
#   - The bar for |1⟩ is 1.
#   - The bar for |0⟩ is 0.
#   - The qubit is definitely in state 1.
#   - If we measure it, we will always get 1.
#   - This behaves like a classical bit set to 1.
# - |+⟩ = (|0⟩ + |1⟩)/√2 (equal superposition)
#   - Both bars are the same height.
#   - The qubit is in a balanced combination of 0 and 1.
#   - If we measure it many times, we will get 0 about 50% of the time and 1 about 50% of the time.
#
# **NOTE:**
# The qubit is not secretly 0 or 1 — it genuinely has both possibilities until measurement.
#
# - |−⟩ = (|0⟩ − |1⟩)/√2 (equal superposition with phase)
#   - The bars have the same magnitude, but one is negative.
#   - The probabilities are still 50% for 0 and 50% for 1.
#   - The only difference is the sign (phase) of one amplitude.
#   - Even though measurement probabilities are the same as |+⟩, this state behaves differently when we apply additional quantum operations because the negative sign affects interference.
#
# - The height of each bar represents amplitude.
# - The square of the height determines probability.
# - The sign (positive or negative) affects interference, even if it does not change the immediate measurement probability.

# %% [markdown]
# <img src="https://raw.githubusercontent.com/FSCJ-FacultyDev/WC26-Summer-QuantumWorkshop/main/images/qubit-amplitudes.png"
#      alt="Qubit Amplitudes"
#      width="75%">

# %% [markdown]
# Note that the above images show amplitudes in the |0>,|1> basis; the Bloch sphere below shows the same state as a point, including phase information that the bar plot (with real amplitudes) doesn't capture.
# - ∣ψ⟩ represents the quantum state of the qubit, shown as a vector from the center of the sphere to a point on its surface.
# - The north pole represents the basis state ∣0⟩ and the south pole represents ∣1⟩.
# - Points between them represent superpositions of these states.
# - **Phase** is the part of a qubit’s state that determines how it combines or interferes with other states (covered later)
# - The angles θ (theta) and φ (phi) determine the position of the state on the sphere, encoding both the relative amplitudes and phase of the qubit.
# - Points on the equator correspond to states with equal probabilities of measuring 0 or 1, differing only in their phase.
#
# <img src="https://raw.githubusercontent.com/FSCJ-FacultyDev/WC26-Summer-QuantumWorkshop/main/images/blochsphere-qubit.png"
#      alt="Bloch Sphere Qubit Representation"
#      width="50%">
# (Frisk Kockum & Nori, 2019)

# %% [markdown]
# ## Compare a classical bit vs. a superposed qubit.
#
# <img src="https://raw.githubusercontent.com/FSCJ-FacultyDev/WC26-Summer-QuantumWorkshop/main/images/classic-vs-superposed.png"
#      alt="Classic Bit vs. Superposed Qubit"
#      width="75%">

# %% [markdown]
# ### Equal Superposition
# - An **equal superposition** is a quantum state where all possible outcomes have equal weight, meaning they have the same probability when measured.
# - After qubits are initialized, equal superposition creates a balanced starting point where no outcome is favored and interference can amplify the correct answer.
# - For a single qubit, an equal superposition is written as (|0> + |1>) / &radic;2
# - In this state:
#   - The amplitudes of |0⟩ and |1⟩ are equal.
#   - Each outcome has a 50% probability when measured.
#   - On a graph, this appears as two bars of equal height.
#
#   <img src="https://raw.githubusercontent.com/FSCJ-FacultyDev/WC26-Summer-QuantumWorkshop/main/images/equal-superposition.png"
#       alt="Equal Superposition"
#       width="50%">
#
#   - On the Bloch sphere, this corresponds to any point on the equator.
#     - Although all equator points give equal measurement probabilities, they can differ in phase, meaning they are not identical states.
# - Equal superposition does not mean the qubit is classically “both 0 and 1”; it means both possibilities are equally weighted before measurement.

# %% [markdown]
# ### Apply a Simple Quantum Operation
# To understand how quantum computation works, we begin with a simple quantum operation called a **gate** (covered in more detail in Day 2).
# - A quantum gate changes the state of a qubit, similar to how a logic gate changes a classical bit.
# - Gates are the basic building blocks of quantum circuits.
# - A **Hadamard gate** (named after French mathematician Jacques Hadamard) is one of the most fundamental quantum gates; it shows us how a qubit can be transformed from a definite state into a superposition.
# - If we start with |0> (ground state), applying the Hadamard gate (H) produces an equal superposition:
#
#   (|0> + |1>) / √2
#
#   - This means the qubit is now equally likely to be measured as 0 or 1.
#
# - A simple circuit diagram of this operation looks like this:
#
#   q0: ──|0⟩──[ H ]──[ M ]──▶ 0/1
#
#   where q0 is the name of the qubit.
#
#   |0⟩: The qubit (q0) starts in the initialized ground state.
#
#   [ H ] The Hadamard gate is applied, which transforms q0 into an equal superposition state.
#
#   [ M ] The qubit is measured, which collapses the superposition to either 0 or 1 with roughly 50% probability each.
#
# - **NOTE** a gate applies a mathematical transformation to the entire state at once. It does not modify values one by one; it transforms the full state in a single step.
# - **NOTE 2** superposition is not a default state; it is produced by a quantum operation.
# - **NOTE 3** on real hardware, a Hadamard gate is implemented by applying a precisely shaped microwave or laser pulse that rotates the qubit's quantum state (changes the direction of its state vector on the Bloch sphere)
#
#   <img src="https://raw.githubusercontent.com/FSCJ-FacultyDev/WC26-Summer-QuantumWorkshop/main/images/hadamard-implementation.png"
#       alt="Hadamard Gate Implementation"
#       width="50%">

# %% [markdown]
# ### Simulate Measurement
# - In the above steps we mathematically transformed a qubit's state using the Hadamard gate.
# - Now let's move from abstract state vectors to observable outcomes.
# - In this step, we will simulate repeated measurements (“shots”) of a qubit, record how often each result occurs, and plot the distribution using some basic Python libraries.
# - You do not need to know Python to follow along, focus on the concepts; the code is simply automating the measurement and counting process for us.
# - This allows us to connect probability amplitudes (from the state vector) to real experimental frequencies, demonstrating how quantum theory predicts measurable behavior.

# %%
import numpy as np
import matplotlib.pyplot as plt

# -----------------------------
# 1. Define the Hadamard gate
# -----------------------------
H = (1 / np.sqrt(2)) * np.array([
    [1,  1],
    [1, -1]
])

# -----------------------------
# 2. Define initial state |0>
# -----------------------------
state = np.array([1, 0], dtype=complex)

print("Initial state |0>:", state)

# -----------------------------
# 3. Apply Hadamard (rotation on Bloch sphere)
# -----------------------------
state = H @ state

print("\nState after applying Hadamard:")
print(state)

# -----------------------------
# 4. Convert amplitudes to probabilities
# -----------------------------
probabilities = np.abs(state)**2

print("\nMeasurement probabilities:")
print(f"P(0) = {probabilities[0]:.4f}")
print(f"P(1) = {probabilities[1]:.4f}")

# -----------------------------
# 5. Simulate repeated measurements (shots)
# -----------------------------
shots = 1000
results = np.random.choice([0, 1], size=shots, p=probabilities)

# -----------------------------
# 6. Plot results
# -----------------------------
count_0 = np.sum(results == 0)
count_1 = np.sum(results == 1)

p0 = count_0 / shots
p1 = count_1 / shots
print(f"Frequencies: P(0)≈{p0:.3f}, P(1)≈{p1:.3f}")

plt.bar(["0", "1"], [count_0, count_1])
plt.title("Measurement Results")
plt.ylabel("Counts")
plt.xlabel("Outcome")
plt.show()
# Out:
# Initial state |0>: [1.+0.j 0.+0.j]
#
# State after applying Hadamard:
# [0.70710678+0.j 0.70710678+0.j]
#
# Measurement probabilities:
# P(0) = 0.5000
# P(1) = 0.5000
# Frequencies: P(0)≈0.481, P(1)≈0.519

# %% [markdown]
# ### Interpreting the Results
# - In this example, the Hadamard transformed |0⟩ into an equal superposition with amplitudes ≈ 0.7071 and theoretical probabilities 0.5000 / 0.5000.
# - Simulating 1000 measurements produced frequencies of approximately 0.517 (for 0) and 0.483 (for 1).
# - The slight imbalance reflects normal statistical fluctuation from finite sampling.
# - Overall, the experimental frequencies closely match the predicted 50/50 quantum probabilities.

# %% [markdown]
# ### Qiskit
# - Qiskit is an open-source quantum computing SDK for building, simulating, and running quantum circuits on real quantum hardware or simulators.
# - The following program recreates the above Hadamard demonstration using Qiskit.
# - Instead of manually multiplying matrices, we build a quantum circuit, apply a Hadamard gate, measure the qubit, and run repeated shots on a simulator to observe the resulting distribution.
# - This approach mirrors how real quantum hardware is programmed, allowing us to connect conceptual quantum operations to practical circuit execution.

# %%
# !pip install qiskit qiskit-aer

import numpy as np
import matplotlib.pyplot as plt

from qiskit import QuantumCircuit, transpile
from qiskit_aer import AerSimulator

# -----------------------------
# Build circuit: |0> -> H -> measure
# -----------------------------
qc = QuantumCircuit(2, 2)   # 1 qubit, 1 classical bit
print("before: \n",qc)
qc.h(0)
qc.h(1)
print(qc)
qc.h(0)      # Hadamard gate
qc.measure(0, 0)            # Measure qubit into classical bit
qc.measure(1,1)

#print(qc)

print("\nafter: ", qc)
# -----------------------------
# Run "shots" on a simulator
# -----------------------------
shots = 1000
sim = AerSimulator()

compiled = transpile(qc, sim)
job = sim.run(compiled, shots=shots)
result = job.result()
counts = result.get_counts(compiled)

print("\nCounts:", counts)

# -----------------------------
# Plot distribution
# -----------------------------
# Ensure both outcomes appear in a consistent order even if one is missing
count_0 = counts.get("0", 0)
count_1 = counts.get("1", 0)

plt.bar(["0", "1"], [count_0, count_1])
plt.title("Measurement Results After Hadamard (Qiskit Aer)")
plt.ylabel("Counts")
plt.xlabel("Outcome")
plt.show()
# Out:
# ...
# before:
#
# q_0:
#
# q_1:
#
# c: 2/
#
#      ┌───┐
# q_0: ┤ H ├
#      ├───┤
# q_1: ┤ H ├
#      └───┘
# c: 2/═════
#
#
# after:       ┌───┐┌───┐┌─┐
# q_0: ┤ H ├┤ H ├┤M├
#      ├───┤└┬─┬┘└╥┘
# q_1: ┤ H ├─┤M├──╫─
#      └───┘ └╥┘  ║
# c: 2/═══════╩═══╩═
#             1   0
#
# Counts: {'10': 514, '00': 486}

# %% [markdown]
# ### Qiskit ASCII
# Qiskit ASCII is a text-based visualization of a quantum circuit that shows qubits, gates, and measurement instructions laid out from left to right in time. It illustrates the structure of the circuit (not the measurement results).
# - Each horizontal line represents a qubit (or classical bit), and boxes or symbols along the line indicate operations applied to that qubit.
# - It provides a quick, readable way to understand the structure and flow of a quantum program without requiring graphical tools.
#
#   <img src="https://raw.githubusercontent.com/FSCJ-FacultyDev/WC26-Summer-QuantumWorkshop/main/images/qiskit-ascii.png"
#       alt="Qiskit ASCII Circuit Diagram"
#       width="25%">
#
# - The top line (q:) represents a single qubit, and operations are applied from left to right in time.
# - The H box is a Hadamard gate, which puts the qubit into equal superposition.
# - The M box measures the qubit, collapsing it to either 0 or 1.
# - The vertical connector shows the measurement result being stored in a classical bit.
# - The bottom double line (c:) is the classical register that records the final 0 or 1 outcome (quantum registers store qubits, classical registers store measurement results as ordinary bits).

# %% [markdown]
# ## Hands-On Exercise 1 Part A: Modify the Shots
# What is the significance of the number of shots in a quantum experiment? Find the "shots = " line in the code block above and change the number of shots, then observe the results.
#
# Try:
#
# - shots = 10
# - shots = 50
# - shots = 100
# - shots = 10000
#
# <details>
#   <summary><strong>Click to reveal expected observation</strong></summary>
#   <p>
#     As you increase the number of shots, the measured frequencies for 0 and 1
#     should move closer to the theoretical probabilities predicted by the quantum
#     state. This shows why repeated measurements are important in quantum
#     computing: a single measurement is random, but many measurements reveal the
#     pattern.
#   </p>
# </details>

# %% [markdown]
# ## Hands-On Exercise 1 Part B: Apply a Second Hadamard Gate
# Find the qc.h(0) line in the circuit definition and add a second qc.h(0) immediately below it. Before running the code, predict what the measurement results will be.
#
# <details>
#   <summary><strong>Click to reveal expected observation</strong></summary>
#   <p>
#     The Hadamard gate is its own inverse, meaning applying it twice cancels the
#     operation. The first Hadamard creates an equal superposition of |0⟩ and |1⟩,
#     and the second Hadamard recombines the amplitudes through interference,
#     returning the qubit to its original state |0⟩. As a result, every measurement produces 0.
#   </p>
# </details>

# %% [markdown]
# ## Why Do Quantum Computers Look So Weird?
# (Post-Quantum, n.d.)
#
# <table>
#   <tr>
#     <td style="padding:10px;"><img src="https://raw.githubusercontent.com/FSCJ-FacultyDev/WC26-Summer-QuantumWorkshop/main/images/quantum-chan.png" width="250"></td>
#     <td style="padding:10px;"><img src="https://raw.githubusercontent.com/FSCJ-FacultyDev/WC26-Summer-QuantumWorkshop/main/images/news-quantum.png" width="250"></td>
#     <td style="padding:10px;"><img src="https://raw.githubusercontent.com/FSCJ-FacultyDev/WC26-Summer-QuantumWorkshop/main/images/google-quantum2.png" width="250"></td>
#   </tr>
# </table>
#
# - Quantum computers resemble chandeliers because their design supports the extreme cooling and shielding required for superconducting qubits.
# - Cryogenic cooling to millikelvin temperatures (20–100 mK) is essential for superconducting qubits; even tiny amounts of thermal energy cause decoherence (the loss quantum state from environmental disturbance) and computational errors.
# - At near-absolute-zero temperatures, materials become superconducting with zero electrical resistance, which enables key quantum computing techniques and preserves coherence.
# - Suspending quantum computers from the ceiling reduces ground-borne mechanical vibrations that could disturb fragile qubit states, creating a more stable operating environment.
# - A "chandelier-style" vertical design improves thermal isolation, maintains ultra-low temperatures, and allows efficient organization of cryogenic stages and wiring for easier maintenance.

# %% [markdown]
# ## Wrap-Up and Homework
# - Superposition, interference, measurement.
# - Mathematical representation of observed behavior.
# - Transitioning to multi-qubit systems / algorithms.
#
# ### Homework! Research Current Quantum Hardware
#
# For next time, research the current number of qubits available on quantum computers from for at least three quantum computing vendors; our goal is to get a sense of how different platforms compare and how quickly the field is evolving. Prepare a short summary (3–5 minutes) to share during the next workshop.
#
# Possible vendors include:
#
# - IBM
# - Google
# - IonQ
# - Rigetti
# - Quantinuum
# - D-Wave
# - Amazon
#
# For each vendor, record:
#
# - The name of the quantum processor or system
# - The number of qubits
# - The technology used (for example: superconducting, trapped ion, photonic, annealing, etc.)
# - The date the system was announced or released

# %% [markdown]
# ## References
#
# - Richard Feynman. (1965). The character of physical law. MIT Press.
# - Griffiths, D. J., & Schroeter, D. F. (2018). Introduction to quantum mechanics (3rd ed.). Cambridge University Press.
# - Suarez, S. (n.d.). If you’re a software engineer, physicist…. LinkedIn. https://www.linkedin.com/posts/stevesuarez_if-youre-a-software-engineer-physicist-activity-7393943126278688769-TLAo/
# - Gonciulea, C., & Stefanski, C. (2025). Building Quantum Software With Python: A Developer’s Guide. Manning Publications. ISBN: 978-1633437630.
# - Ishuah. (2021, December 19). A benchmark study: SIMD intrinsics. https://ishuah.com/2021/12/19/a-benchmark-study-simd-intrinsics/
# - National Institute of Standards and Technology. (2024, August 13). NIST releases first 3 finalized post-quantum encryption standards. U.S. Department of Commerce. https://www.nist.gov/news-events/news/2024/08/nist-releases-first-3-finalized-post-quantum-encryption-standards
# - Reuters. (2026, March 19). China likely to have standards for post-quantum cryptography in 3 years. https://www.reuters.com/world/asia-pacific/china-likely-have-standards-post-quantum-crytography-3-years-expert-says-2026-03-19/
# - 3Blue1Brown. Imaginary Numbers Are Real. YouTube. https://www.youtube.com/watch?v=BJ6b9t0ryhU
# - https://economictimes.indiatimes.com/news/international/australia/quote-of-the-day-by-niels-bohr-an-expert-is-a-person-who-has-made-all-the-mistakes-that-can-be-made-in-a-very-narrow-field
# - Wikipedia contributors. (n.d.). Timeline of quantum computing and communication. In Wikipedia. Retrieved March 16, 2026, from
# https://en.wikipedia.org/wiki/Timeline_of_quantum_computing_and_communication
# - IBM Quantum. (n.d.). Bloch sphere. https://quantum.cloud.ibm.com/learning/en/courses/general-formulation-of-quantum-information/density-matrices/bloch-sphere
# - Prof. nano. (n.d.). Mapping the qubit state onto the Bloch sphere [Video]. YouTube. https://www.youtube.com/watch?v=lqWSziZJsLs
# - Place, A.P.M., Rodgers, L.V.H., Mundada, P. et al. New material platform for superconducting transmon qubits with coherence times exceeding 0.3 milliseconds. Nat Commun 12, 1779 (2021). https://doi.org/10.1038/s41467-021-22030-5
# - Schindler, P., Nigg, D., Monz, T., Barreiro, J. T., Martínez, E., Wang, S. X., Quint, S., Brandl, M. F., Nebendahl, V., Roos, C. F., & Blatt, R. (2013). A quantum information processor with trapped ions. New Journal of Physics, 15(12), 123012. https://doi.org/10.1088/1367-2630/15/12/123012
# - Swayne, M. (2025, June 5). Xanadu demonstrates scalable building block for photonic quantum computers. The Quantum Insider. https://thequantuminsider.com/2025/06/05/xanadu-demonstrates-scalable-building-block-for-photonic-quantum-computers/
# - Frisk Kockum, Anton & Nori, Franco. (2019). Quantum Bits with Josephson Junctions. 10.1007/978-3-030-20726-7_17.
# - Post-Quantum. (n.d.). Why are quantum computers so weird? https://postquantum.com/quantum-computing/quantum-computer-weird/
# - QuSecure. (n.d.). Qubit scorecard. https://www.qusecure.com/qubit-scorecard/
